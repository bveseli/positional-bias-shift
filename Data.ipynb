# %%
import pandas as pd

# %% [markdown]
# # Base instances

# %%
base_instances = pd.read_json("data/base_instances.jsonl", lines=True)
base_instances.head()
# Out:
#    sample_id               dataset  \
# 0          0  Simplified RuleTaker
# 1          1  Simplified RuleTaker
# 2          2  Simplified RuleTaker
# 3          3  Simplified RuleTaker
# 4          4  Simplified RuleTaker
#
#                                                mixin label  ctx_size  \
# 0  If X is good and X is small then X is loud. Da...  True       250
# 1  If X is good and X is lazy then X is red. Bob ...  True       250
# 2  If X is good and X is tall then X is dumb. Har...  True       250
# 3  If X is furry and X is flat then X is fast. Fi...  True       250
# 4  If X is nice and X is dumb then X is lazy. Dav...  True       250
#
#   assertion/question retrieval_assertion/question world_states
# 0      Dave is loud.      Dave is small and good.         None
# 1        Bob is red.        Bob is good and lazy.         None
# 2     Harry is dumb.      Harry is tall and good.         None
# 3     Fiona is fast.     Fiona is furry and flat.         None
# ...

# %% [markdown]
# # Retrieval Reasoning Minimalpairs

# %%
reasoning_retrieval_minimalpairs = pd.read_json("data/reasoning_retrieval_dataset.jsonl", lines=True)
reasoning_retrieval_minimalpairs.head()
# Out:
#    sample_id  dataset                                              mixin  \
# 0          0  MonoRel  julie baker is younger than julian barton. thi...
# 1          0  MonoRel  usually , he would be tearing around the livin...
# 2          0  MonoRel  usually , he would be tearing around the livin...
# 3          1  MonoRel  matthew thomas is younger than melissa brown. ...
# 4          1  MonoRel  usually , he would be tearing around the livin...
#
#   label dispersion padding_type  \
# 0  True      first        books
# 1  True       last        books
# 2  True     middle        books
# 3  True      first        books
# 4  True       last        books
#
#                                   assertion/question  \
# 0  After performing all operations Box 1 contains...
# 1  After performing all operations Box 1 contains...
# 2  After performing all operations Box 1 contains...
# 3  After performing all operations Box 1 contains...
# 4  After performing all operations Box 1 contains...
#
# ...

# %% [markdown]
# # Wikipedia Dataset

# %%
wikipedia_dataset = pd.read_json("data/wikipedia_dataset.jsonl", lines=True)
wikipedia_dataset.head()
# Out:
#    sample_id position                                           wikipage  \
# 0         71   middle  Document: Burgess Model H\nThe Burgess Model H...
# 1        125   middle  Document: Fighter Bomber\nFighter Bomber (rele...
# 2        121   middle  Document: Crafting Mama\nCrafting Mama, known ...
# 3        293    first  Document: Jonathan Ship\nJonathan Andrew Ship ...
# 4        230     last  Document: The Story of PuPu\nThe Story of PuPu...
#
#                                                mixin relation  \
# 0  The City of Metronome was a cancelled 3D puzzl...     P176
# 1  Fun Spot America Theme Parks is a group of amu...     P178
# 2  The Luxembourgish Patriot League (LPL, Luxembo...     P178
# 3  Document: Jonathan Ship\nJonathan Andrew Ship ...      P19
# 4  Kent L. Norman is an American cognitive psycho...     P364
#
#                                                 desc  \
# 0  manufacturer;manufacturer or producer of this ...
# ...
